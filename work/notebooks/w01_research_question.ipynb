# %% [markdown]
# <a href="https://colab.research.google.com/github/Avani-25/FlyRank---ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Avani-25/FlyRank---ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Lane: Content refresh prioritization. Notebook 1 showed a learned model beating a hand-written rule by roughly 3x on this exact problem, which made me want to understand why the simple rule fails and what signals the model is actually picking up on that a human wouldn't think to check.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Decision: Which pages in a site's content library should be refreshed first, given limited editor time.
# Who acts on it: A content/SEO editor with a fixed number of hours per week — they can't fix everything, so they need a ranked queue.
# Cost of a wrong call: If we rank a stable, healthy page as high-priority, the editor wastes hours reworking something that didn't need it. If we rank a genuinely declining page as low-priority, it keeps losing traffic/rankings until someone notices it manually — a missed decline that compounds over time.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My question is "which ones first" → Ranking/scoring task. Target: a priority score per page. Metric: precision@K (are the top-K pages I flag actually the ones that most needed attention?).

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# For a content/SEO editor, deciding which pages to refresh first, we will build a ranked priority queue from page-level search performance signals (clicks, impressions, position trends, content age, etc.), scoring likelihood of continued decline measured by precision@K against pages that were later confirmed to decline. A wrong call costs either wasted editor hours on stable pages or a missed decline that keeps losing traffic. A plain if-statement rule isn't enough because decline is driven by many tangled signals shifting over time, not one clean threshold. We will claim only decision-support results — a prioritized list to guide editors, not a guarantee of what will happen to any single page.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
